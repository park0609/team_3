# %%
# 0304 3조 팀과제 !!

# %% [markdown]
# ------------------------------------------------------
# - 연습문제 스터디 조원별로 나눠풀기

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm

# %%
# 윈도우용 폰트 경로 설정
path = "C:\\Windows\\Fonts\\NanumGothic.ttf"
font_name = fm.FontProperties(fname=path).get_name()
rc('font',family=font_name)
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
import pandas as pd
file_path = "./data ref/IRIS.csv"
iris_data = pd.read_csv(file_path)
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris_c = iris_data.copy()
iris_c = iris_data.groupby(['class']).sum()
print(iris_c.index)
# Out:
# Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object', name='class')

# %%
print(len(iris_c.index))
# Out:
# 3

# %%
print(iris_c)
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# class
# Iris-setosa             250.3        170.9          73.2         12.2
# Iris-versicolor         296.8        138.5         213.0         66.3
# Iris-virginica          329.4        148.7         277.6        101.3

# %%
# Q21
iris_s = iris_data.copy()
iris_s1 = iris_s.loc[:,'petal_length':'class']
iris_s1 = iris_s1.groupby('class').size()
iris_s1
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
iris_data = iris_data.sort_index(axis=1, ascending=False)
iris_data
# Out:
#      sepal_width  sepal_length  petal_width  petal_length           class
# 0            3.5           5.1          0.2           1.4     Iris-setosa
# 1            3.0           4.9          0.2           1.4     Iris-setosa
# 2            3.2           4.7          0.2           1.3     Iris-setosa
# 3            3.1           4.6          0.2           1.5     Iris-setosa
# 4            3.6           5.0          0.2           1.4     Iris-setosa
# ..           ...           ...          ...           ...             ...
# 145          3.0           6.7          2.3           5.2  Iris-virginica
# 146          2.5           6.3          1.9           5.0  Iris-virginica
# 147          3.0           6.5          2.0           5.2  Iris-virginica
# 148          3.4           6.2          2.3           5.4  Iris-virginica
# 149          3.0           5.9          1.8           5.1  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Q22
iris_data.loc[:10,'sepal_length']
# Out:
# 0     5.1
# 1     4.9
# 2     4.7
# 3     4.6
# 4     5.0
# 5     5.4
# 6     4.6
# 7     5.0
# 8     4.4
# 9     4.9
# 10    5.4
# Name: sepal_length, dtype: float64

# %%
# Q23
iris_data.loc[5:19,'sepal_length']
# Out:
# 5     5.4
# 6     4.6
# 7     5.0
# 8     4.4
# 9     4.9
# 10    5.4
# 11    4.8
# 12    4.8
# 13    4.3
# 14    5.8
# 15    5.7
# 16    5.4
# 17    5.1
# 18    5.7
# 19    5.1
# Name: sepal_length, dtype: float64

# %%
# Q24
iris_data.loc[:,'sepal_length']/iris_data.loc[:, 'petal_length'].astype(float)
# Out:
# 0      3.642857
# 1      3.500000
# 2      3.615385
# 3      3.066667
# 4      3.571429
#          ...
# 145    1.288462
# 146    1.260000
# 147    1.250000
# 148    1.148148
# 149    1.156863
# Length: 150, dtype: float64

# %%
# Q25
iris_data[iris_data['sepal_length']>5]
# Out:
#      sepal_width  sepal_length  petal_width  petal_length           class
# 0            3.5           5.1          0.2           1.4     Iris-setosa
# 5            3.9           5.4          0.4           1.7     Iris-setosa
# 10           3.7           5.4          0.2           1.5     Iris-setosa
# 14           4.0           5.8          0.2           1.2     Iris-setosa
# 15           4.4           5.7          0.4           1.5     Iris-setosa
# ..           ...           ...          ...           ...             ...
# 145          3.0           6.7          2.3           5.2  Iris-virginica
# 146          2.5           6.3          1.9           5.0  Iris-virginica
# 147          3.0           6.5          2.0           5.2  Iris-virginica
# 148          3.4           6.2          2.3           5.4  Iris-virginica
# 149          3.0           5.9          1.8           5.1  Iris-virginica
#
# [118 rows x 5 columns]

# %% [markdown]
# ___________________________
# - 연령별취업자수관계 데이터를 이용해서 팀별상의하여 의미있는 인사이트 도출하기(1가지만)

# %%
import pandas as pd
file_path = "./data ref/행정구역_시도__성_연령별_취업자.csv"
ori = pd.read_csv(file_path,encoding="EUC-KR")
ori.head()
# Out:
#      시도별        시점     연령계층별  성별  데이터
# 0  서울특별시  2014.1/4  20 - 29세  남자  331
# 1  서울특별시  2014.1/4  20 - 29세  여자  460
# 2  서울특별시  2014.1/4  30 - 39세  남자  774
# 3  서울특별시  2014.1/4  30 - 39세  여자  519
# 4  서울특별시  2014.1/4  40 - 49세  남자  773

# %%
ex_data = ori.copy()
ex_data.columns = ['region','year','age','gender','value']
ex_data.loc[ex_data['region']=='세종특별자치시','value']=ex_data.loc[ex_data['region']=='세종특별자치시','value'].replace('-',0)
ex_data
# Out:
#      region      year       age gender value
# 0     서울특별시  2014.1/4  20 - 29세     남자   331
# 1     서울특별시  2014.1/4  20 - 29세     여자   460
# 2     서울특별시  2014.1/4  30 - 39세     남자   774
# 3     서울특별시  2014.1/4  30 - 39세     여자   519
# 4     서울특별시  2014.1/4  40 - 49세     남자   773
# ...     ...       ...       ...    ...   ...
# 7435    제주도  2024.4/4  40 - 49세     여자    44
# 7436    제주도  2024.4/4  50 - 59세     남자    54
# 7437    제주도  2024.4/4  50 - 59세     여자    47
# 7438    제주도  2024.4/4     60세이상     남자    49
# 7439    제주도  2024.4/4     60세이상     여자    49
#
# [7440 rows x 5 columns]

# %%
ex_data['value'] = ex_data['value'].astype(int)
ex1_data = ex_data.groupby('year')['value'].sum().reset_index(name="total")

# %%
busan_data = ori.copy()
busan_data.columns = ['region','year','age','gender','value']
busan_data.loc[busan_data['region']=='세종특별자치시','value']=busan_data.loc[busan_data['region']=='세종특별자치시','value'].replace('-',0)
busan_data
# Out:
#      region      year       age gender value
# 0     서울특별시  2014.1/4  20 - 29세     남자   331
# 1     서울특별시  2014.1/4  20 - 29세     여자   460
# 2     서울특별시  2014.1/4  30 - 39세     남자   774
# 3     서울특별시  2014.1/4  30 - 39세     여자   519
# 4     서울특별시  2014.1/4  40 - 49세     남자   773
# ...     ...       ...       ...    ...   ...
# 7435    제주도  2024.4/4  40 - 49세     여자    44
# 7436    제주도  2024.4/4  50 - 59세     남자    54
# 7437    제주도  2024.4/4  50 - 59세     여자    47
# 7438    제주도  2024.4/4     60세이상     남자    49
# 7439    제주도  2024.4/4     60세이상     여자    49
#
# [7440 rows x 5 columns]

# %%
busan_data.loc[:,'value'] = busan_data.loc[:,'value'].astype(int)
busan_data = busan_data.loc[busan_data['region']=='부산광역시']
busan_gen = busan_data.groupby(['year','gender'])['value'].sum().reset_index(name='total')

# %%
filter_m = busan_gen['gender']=='남자'
filter_f= busan_gen['gender'] =='여자'
male = busan_gen[filter_m]
female = busan_gen[filter_f]

# %%
plt.figure(figsize=(20,5))
plt.plot(male['year'],male['total'],label='남자',color="blue",linestyle='-', marker='o')
plt.plot(male['year'],female['total'],label='남자',color="red",linestyle='-', marker='x')
plt.xticks(range(len(ex1_data)))
plt.xticks(ex1_data['year'],rotation=45)
plt.show()
